# %%
import pandas as pd
import numpy as np
import os
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
# filepath = "merged_u1-50_w001_resampled.csv"
filepath = "D:/online dataset csv files preprocessing/merged_u1-50_w001_resampled.csv"

df_original = pd.read_csv(filepath)

# %%
df_original
# Out:
#                 timestamp       LAx       LAy       LAz       GYx       GYy  \
# 0         924313410000000  1.242813 -0.160181 -0.900440  0.194931 -0.004242
# 1         924313420000000  1.117246 -0.187921 -1.529893  0.236458  0.076378
# 2         924313430000000  0.912846 -0.192566 -1.570929  0.226074  0.012253
# 3         924313440000000  0.874858 -0.227208 -1.453511  0.139336 -0.050667
# 4         924313450000000  0.834022 -0.282976 -1.292671 -0.013374 -0.109314
# ...                   ...       ...       ...       ...       ...       ...
# 2055043  1368327120000000 -9.502644 -7.178468  4.246279 -2.834417 -0.120428
# 2055044  1368327130000000 -9.443804 -7.698220  3.059675 -2.638940  0.561997
# 2055045  1368327140000000 -8.345459 -6.805815  1.853457 -2.483606  1.225222
# 2055046  1368327150000000 -7.580540 -5.629017  1.559257 -2.429500  1.769765
# 2055047  1368327160000000 -6.952915 -4.589512  1.755390 -2.426010  2.099633
#
#               GYz  name
# 0        0.163818     1
# 1        0.133293     1
# 2        0.108246     1
# 3        0.085030     1
# 4        0.078308     1
# ...           ...   ...
# 2055043 -0.987857    50
# 2055044 -0.947715    50
# 2055045 -0.954696    50
# 2055046 -1.003565    50
# 2055047 -0.980876    50
#
# [2055048 rows x 8 columns]

# %%
df_Xtime = df_original.copy()
df_Xtime = df_Xtime.drop(['timestamp'], axis = 1).copy()
df_Xtime.shape
# Out:
# (2055048, 7)

# %%
X = df_Xtime[['LAx', 'LAy', 'LAz','GYx', 'GYy', 'GYz']].copy()
y = df_Xtime['name'].copy()

# %%
scaler = StandardScaler()
X_transformed = X.copy()
X_transformed = scaler.fit_transform(X_transformed)

scaled_X = pd.DataFrame(data = X_transformed, columns = ['LAx', 'LAy', 'LAz','GYx', 'GYy', 'GYz'])
scaled_X['label'] = y.values

scaled_X
# Out:
#               LAx       LAy       LAz       GYx       GYy       GYz  label
# 0        0.359745 -0.067021 -0.237446  0.105221  0.035341  0.175545      1
# 1        0.322625 -0.073783 -0.418039  0.133911  0.092852  0.143484      1
# 2        0.262201 -0.074915 -0.429812  0.126737  0.047108  0.117177      1
# 3        0.250972 -0.083358 -0.396125  0.066811  0.002223  0.092793      1
# 4        0.238900 -0.096951 -0.349979 -0.038693 -0.039614  0.085733      1
# ...           ...       ...       ...       ...       ...       ...    ...
# 2055043 -2.816791 -1.777656  1.239172 -1.987696 -0.047543 -1.034070     50
# 2055044 -2.799397 -1.904341  0.898730 -1.852644  0.439278 -0.991908     50
# 2055045 -2.474708 -1.686826  0.552660 -1.745327  0.912402 -0.999240     50
# 2055046 -2.248585 -1.399994  0.468253 -1.707947  1.300863 -1.050568     50
# 2055047 -2.063049 -1.146625  0.524524 -1.705535  1.536180 -1.026737     50
#
# [2055048 rows x 7 columns]

# %%
import scipy.stats as stats

Fs = 100
frame_size = Fs*6
hop_size = Fs*2

# %%
num_columns = frame_size*6
new_df = pd.DataFrame(columns=range(num_columns))
for i in range(0,num_columns):
    if i in range(0,frame_size):
        string = f"LAx_{i+1}"
        new_df = new_df.rename(columns={i: string})
        
    if i in range(frame_size,frame_size*2):
        string = f"LAy_{i+1}"
        new_df = new_df.rename(columns={i: string}) 
       
    if i in range(frame_size*2,frame_size*3):
        string = f"LAz_{i+1}"
        new_df = new_df.rename(columns={i: string}) 
       
    if i in range(frame_size*3,frame_size*4):
        string = f"GYx_{i+1}"
        new_df = new_df.rename(columns={i: string})
        
    if i in range(frame_size*4,frame_size*5):
        string = f"GYy_{i+1}"
        new_df = new_df.rename(columns={i: string}) 
       
    if i in range(frame_size*5,frame_size*6):
        string = f"GYz_{i+1}"
        new_df = new_df.rename(columns={i: string})

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [LAx_1, LAx_2, LAx_3, LAx_4, LAx_5, LAx_6, LAx_7, LAx_8, LAx_9, LAx_10, LAx_11, LAx_12, LAx_13, LAx_14, LAx_15, LAx_16, LAx_17, LAx_18, LAx_19, LAx_20, LAx_21, LAx_22, LAx_23, LAx_24, LAx_25, LAx_26, LAx_27, LAx_28, LAx_29, LAx_30, LAx_31, LAx_32, LAx_33, LAx_34, LAx_35, LAx_36, LAx_37, LAx_38, LAx_39, LAx_40, LAx_41, LAx_42, LAx_43, LAx_44, LAx_45, LAx_46, LAx_47, LAx_48, LAx_49, LAx_50, LAx_51, LAx_52, LAx_53, LAx_54, LAx_55, LAx_56, LAx_57, LAx_58, LAx_59, LAx_60, LAx_61, LAx_62, LAx_63, LAx_64, LAx_65, LAx_66, LAx_67, LAx_68, LAx_69, LAx_70, LAx_71, LAx_72, LAx_73, LAx_74, LAx_75, LAx_76, LAx_77, LAx_78, LAx_79, LAx_80, LAx_81, LAx_82, LAx_83, LAx_84, LAx_85, LAx_86, LAx_87, LAx_88, LAx_89, LAx_90, LAx_91, LAx_92, LAx_93, LAx_94, LAx_95, LAx_96, LAx_97, LAx_98, LAx_99, LAx_100, ...]
# Index: []
#
# [0 rows x 3600 columns]

# %%
label = []
def get_frames(scaled_X, frame_size, hop_size):
    df = scaled_X.copy()
    
    last_value = df['label'].iloc[-1]
    
    for j in range (1,last_value+1):
        filtered_df = df[df['label'] == j]
        filtered_df = filtered_df.drop('label', axis = 1)
        for i in range(0, len(filtered_df) - frame_size, hop_size):
            
            LAx = filtered_df['LAx'].values[i: i + frame_size]
            LAy = filtered_df['LAy'].values[i: i + frame_size]
            LAz = filtered_df['LAz'].values[i: i + frame_size]
            GYx = filtered_df['GYx'].values[i: i + frame_size]
            GYy = filtered_df['GYy'].values[i: i + frame_size]
            GYz = filtered_df['GYz'].values[i: i + frame_size]
            
            if(len(LAx) != frame_size):
                x=x+1
                continue
            
            label.append(j)
           
            merged_array = np.concatenate((LAx, LAy, LAz, GYx, GYy , GYz))
            new_df.loc[len(new_df)] = merged_array

# %%
get_frames(scaled_X,frame_size, hop_size)

# %%
new_df
# Out:
#           LAx_1     LAx_2     LAx_3     LAx_4     LAx_5     LAx_6     LAx_7  \
# 0      0.359745  0.322625  0.262201  0.250972  0.238900  0.222485  0.207377
# 1     -0.160100  0.272762  0.715993  1.002722  1.078771  0.593853 -0.202447
# 2      0.008214 -0.090216 -0.246057 -0.413134 -0.535286 -0.589035 -0.754665
# 3     -0.169076 -0.164402 -0.151805 -0.272731 -0.597051 -0.593171 -0.444264
# 4      0.346241  0.138670  0.070654  0.117449  0.171149  0.173999  0.032750
# ...         ...       ...       ...       ...       ...       ...       ...
# 10137 -0.575857 -0.543968 -0.329441  0.067723  0.482281  0.688111  1.354883
# 10138 -0.091722  0.059026 -0.352633 -0.503382 -0.703413 -0.886051 -1.068689
# 10139 -0.080126 -0.378724 -0.546867 -0.575857 -0.596150 -0.832419 -1.051295
# 10140  1.007002  0.986709  0.772182  0.760586  1.064982  1.554915  1.911493
# 10141  0.086567  0.456190  0.806970  0.902638  0.978012  0.879446  0.841759
#
#           LAx_8     LAx_9    LAx_10  ...  GYz_3591  GYz_3592  GYz_3593  \
# 0      0.191340  0.185856  0.181450  ...  0.190963  0.170433  0.169784
# 1     -0.637847 -0.979036 -1.173526  ...  0.240153  1.309896  1.540869
# 2     -0.994857 -1.141323 -1.145324  ... -0.595615 -0.620632 -0.598179
# 3     -0.133798 -0.009714  0.037284  ... -3.214607 -3.050352 -2.999036
# 4     -0.174406 -0.195641 -0.169054  ...  0.146681  0.049818 -0.077849
# ...         ...       ...       ...  ...       ...       ...       ...
# 10137  1.598400  0.986709  0.215573  ...  0.615753  0.679912  0.762403
# 10138 -1.184649 -1.164356 -1.236831  ...  1.127198  1.310511  1.147362
# 10139 -1.619500 -2.187706 -2.547183  ... -0.238489  0.300453  0.894389
# 10140  1.888301  1.543319  1.230226  ... -0.075340 -0.068007 -0.024012
# 10141  0.766384  0.647525  0.461988  ... -1.162389 -0.999240 -0.852589
#
#        GYz_3594  GYz_3595  GYz_3596  GYz_3597  GYz_3598  GYz_3599  GYz_3600
# 0      0.172981  0.184536  0.213424  0.211492  0.195442  0.187116  0.184552
# 1      0.894154 -0.049634 -0.582145 -0.500017  0.015177  0.438611  0.720917
# 2     -0.545572 -0.530812 -0.526317 -0.471138 -0.380043 -0.305617 -0.285720
# 3     -2.896376 -2.544133 -2.087957 -1.534267 -1.072962 -0.485262 -0.032286
# 4     -0.138797 -0.206165 -0.319728 -0.462163 -0.619999 -0.767563 -0.867656
# ...         ...       ...       ...       ...       ...       ...       ...
# 10137  0.837562  0.892556  0.947550  1.057538  1.008044  0.903555  0.764237
# 10138  0.494766 -0.113835 -0.245821 -0.126667  0.096975  0.353614  0.566258
# 10139  1.330676  1.338008  0.931052  0.656082  0.531428  0.613919  0.575424
# 10140  0.080477  0.261957  0.447104  0.516763  0.430606 -0.036844 -0.601450
# 10141 -0.711438 -0.538206 -0.446091 -0.353976 -0.300815 -0.278818 -0.269652
#
# [10142 rows x 3600 columns]

# %%
y = np.array(label)

# %%
new_df_copy = new_df.copy()
new_df_copy['name']= y
# new_df_copy.to_csv('VALUES_AS_FEATURES_FRAMED_RESAMPLED_merged_u1-50_w001_resampled.csv', index = False)

# %%
y = y -1
y
# Out:
# array([ 0,  0,  0, ..., 49, 49, 49])

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(new_df, y, test_size = 0.3, random_state = 0, stratify = y)

X_train, X_validation, y_train, y_validation = train_test_split(X_train_val, y_train_val, test_size = 0.1, random_state = 0, stratify = y_train_val)
X_train.shape, X_test.shape, X_validation.shape, y_train.shape, y_test.shape, y_validation.shape
# Out:
# ((6389, 3600), (3043, 3600), (710, 3600), (6389,), (3043,), (710,))

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test)
dval = xgb.DMatrix(X_validation, label=y_validation)

# %%
dtrain, dtest, dval
# Out:
# (<xgboost.core.DMatrix at 0x27cd028b010>,
#  <xgboost.core.DMatrix at 0x27cd02886d0>,
#  <xgboost.core.DMatrix at 0x27cd02887c0>)

# %%
params = {
    'max_depth': 7,
    'learning_rate': 0.3,
    'objective': 'multi:softmax',
    'num_class': 50
}
epochs = 25
evals_result = {}  # Initialize an empty dictionary to store the evaluation results

# %%
# model = xgb.train(params, dtrain, epochs,  verbose_eval=1)

# %%
model = xgb.train(params, dtrain, epochs, evals=[(dtrain, 'train'), (dval, 'valid')],
                  evals_result=evals_result, verbose_eval=1)
# Out:
# [0]	train-mlogloss:2.27102	valid-mlogloss:3.11843
# [1]	train-mlogloss:1.61566	valid-mlogloss:2.77955
# [2]	train-mlogloss:1.21956	valid-mlogloss:2.57277
# [3]	train-mlogloss:0.94854	valid-mlogloss:2.41876
# [4]	train-mlogloss:0.75441	valid-mlogloss:2.29499
# [5]	train-mlogloss:0.61298	valid-mlogloss:2.18718
# [6]	train-mlogloss:0.50355	valid-mlogloss:2.09785
# [7]	train-mlogloss:0.41969	valid-mlogloss:2.01707
# [8]	train-mlogloss:0.35403	valid-mlogloss:1.94409
# [9]	train-mlogloss:0.30229	valid-mlogloss:1.88705
# [10]	train-mlogloss:0.25952	valid-mlogloss:1.83231
# [11]	train-mlogloss:0.22616	valid-mlogloss:1.77977
# [12]	train-mlogloss:0.19819	valid-mlogloss:1.73069
# [13]	train-mlogloss:0.17499	valid-mlogloss:1.68806
# [14]	train-mlogloss:0.15659	valid-mlogloss:1.64785
# [15]	train-mlogloss:0.14185	valid-mlogloss:1.60775
# [16]	train-mlogloss:0.12928	valid-mlogloss:1.57700
# [17]	train-mlogloss:0.11936	valid-mlogloss:1.54598
# [18]	train-mlogloss:0.11096	valid-mlogloss:1.51848
# [19]	train-mlogloss:0.10391	valid-mlogloss:1.49264
# [20]	train-mlogloss:0.09806	valid-mlogloss:1.46612
# [21]	train-mlogloss:0.09324	valid-mlogloss:1.44679
# [22]	train-mlogloss:0.08915	valid-mlogloss:1.42800
# [23]	train-mlogloss:0.08551	valid-mlogloss:1.41011
# [24]	train-mlogloss:0.08271	valid-mlogloss:1.39721

# %%
predictions = model.predict(dtest)

# %%
print(predictions)
# Out:
# [ 7. 17. 41. ... 17. 17. 40.]

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.7035819914558002

# %%
# new_df_copy

# %%
# new_df_copy.to_csv('VALUES_AS_FEATURES_FRAMED_RESAMPLED_merged_u1-50_w001_resampled.csv', index = False)

# %%
# xgb_model = xgb.XGBClassifier()

# %%
# param_grid = {
#     'max_depth': [3, 5, 7],
#     'learning_rate': [0.1,0.2, 0.3],
# #     'n_estimators': [100, 200, 300],
#     'objective': ['multi:softmax'],
#     'num_class': [50] 
# }

# %%
# grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5)
# grid_search.fit(X_train, y_train)  # X and y are your training data

# %%
# best_params = grid_search.best_params_
# best_model = grid_search.best_estimator_
# best_score = grid_search.best_score_

# %%
# best_params

# %%
# y_pred = best_model.predict(X_test)

# # Evaluate the predictions
# accuracy = accuracy_score(y_test, y_pred)
# accuracy
