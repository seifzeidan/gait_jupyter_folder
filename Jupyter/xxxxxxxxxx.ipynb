# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import seaborn as sns # for plotting.
import os
import math

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])

# %%
directory = os.path.join(os.getcwd(), 'backpack\\training')
x = 1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        try:
            testOriginal = pd.read_csv(filepath)
            test = testOriginal.copy()
            num_rows_before = test.shape[0]

            fivePercent = num_rows_before * 0.20
            fivePercent = math.ceil(fivePercent)
            
            real_fivePercent = num_rows_before * 0.1
            real_fivePercent = math.ceil(fivePercent)

            #test = test.iloc[real_fivePercent:]
            test = test.iloc[:-fivePercent]

            num_rows = test.shape[0]
            # Create a new row of data
            new_row = [
                filepath[55:69],
                test['LA(x)'].mean(), test['LA(y)'].mean(), test['LA(z)'].mean(),
                test['GY(x)'].mean(), test['GY(y)'].mean(), test['GY(z)'].mean(),
                test['LA(x)'].std(), test['LA(y)'].std(), test['LA(z)'].std(),
                test['GY(x)'].std(), test['GY(y)'].std(), test['GY(z)'].std()
            ]

            # Add the new row to the DataFrame
            df.loc[len(df)] = new_row
        except Exception as e:
            print(f"Error occurred while reading file: {filename}")
            print(f"Error message: {str(e)}")
            continue

# %%
df
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0   damirBackpack.    0.173140   -0.362729   -0.304252    0.031552
# 1   udBackpack.csv    0.185752    0.174124   -0.336641   -0.022657
# 2   xBackpackx150x    0.374895    0.067851    0.649481    0.077865
# 3   hxBackpackx726    0.178686   -0.166713    0.475920    0.014834
# 4   alyBackpack.cs    0.111783   -0.433144   -0.417921   -0.017812
# 5   batarabayBackp    0.208458   -0.141582   -0.160986   -0.006641
# 6   nabulxBackpack    0.224665    0.084392    0.432724    0.059310
# 7   emdakrouryxBac   -0.050529   -0.550069    0.530442    0.025622
# 8    iBackpack.csv    0.608332   -0.438298    0.809968   -0.109700
# 9   anyBackpack.cs    0.464066   -0.516951   -0.437352    0.024444
# 10  ilBackpack.csv   -0.080248   -0.473817   -0.651985   -0.056057
# 11   hBackpack.csv    0.018211   -0.084585    0.246519   -0.089954
# 12    Backpack.csv    0.032419   -0.048211    0.278499   -0.033532
# 13  nxBackpackx727    0.060843   -0.118921    0.291233   -0.000720
# 14  rahmedxBackpac    0.080295   -0.033566    0.519944    0.127773
# 15    Backpack.csv    0.260765   -0.039654    0.515398    0.035173
# 16  aztarekBackpac    0.194859   -0.412887    0.644415    0.236098
# 17  medDawodBackpa    0.177092    0.101428    0.575278   -0.025953
# 18  medelshouraBac    0.048796   -0.325339    0.652739   -0.021387
# 19  mmddBackpack.c   -0.073835   -0.631035    0.409352    0.002620
# 20  han2Backpack.c   -0.036326   -0.067695    0.347675   -0.160543
# 21     ackpack.csv    0.051690   -0.287569    0.267416   -0.011164
# 22    Backpack.csv    0.166638    0.035656    0.357881   -0.007260
#
#     mean_GY(y)  mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  \
# 0    -0.237884    0.083588  2.859100  2.867278  3.826793  1.097045  0.777185
# 1     0.093827    0.091212  1.494032  2.540328  1.943992  1.164921  1.167235
# 2    -0.489211   -0.037927  1.756166  3.771635  2.815990  0.718165  1.428170
# 3    -0.150377   -0.018530  2.676458  2.077343  2.267622  0.583846  1.297955
# 4    -0.400863    0.090023  3.318476  3.356504  3.908902  1.198260  1.358760
# 5    -0.150630    0.035445  1.638030  1.883974  1.473826  0.552574  0.938636
# 6    -0.395847    0.039624  1.838944  2.292370  1.724860  0.485338  1.135749
# 7     0.190021   -0.054816  3.791056  3.102421  3.623300  1.211993  1.196973
# 8    -0.597485   -0.129551  2.586825  3.274957  3.083887  1.036623  1.142425
# 9    -0.404135    0.095487  4.266029  4.227338  4.495964  1.152665  1.363092
# 10   -0.440621    0.114939  3.303495  3.082101  4.343135  1.183130  1.689904
# 11    0.495236    0.089475  1.851759  2.234073  1.588229  0.423044  0.908659
# 12    0.171618   -0.004188  1.313335  2.139008  1.569074  0.369310  1.009167
# 13    0.486094    0.050412  2.050625  2.078332  2.057279  0.660661  0.907377
# 14   -0.395082   -0.063546  1.529137  1.869428  1.492061  0.524531  0.877886
# 15   -0.547417   -0.017539  1.448708  1.959189  1.546230  0.610491  1.139611
# 16   -0.392229   -0.097366  3.837957  2.096841  3.870308  0.997571  1.462269
# 17   -0.233091   -0.086481  1.614310  2.800086  2.219401  1.163054  1.269114
# 18   -0.442043   -0.097110  2.185065  2.774451  2.843697  1.020901  1.058725
# 19    0.100124   -0.017143  5.374921  3.617437  4.620766  1.104431  1.424394
# 20    0.412989    0.010776  1.227084  1.601409  1.861783  0.480421  0.760038
# 21    0.181223   -0.015049  4.266359  1.932189  1.810843  0.605887  1.288164
# 22   -0.146467    0.029661  1.387525  1.661000  1.391092  0.410860  1.071594
#
#     sd_GY(z)
# 0   0.659330
# 1   0.520876
# 2   0.424324
# 3   0.659447
# 4   0.613796
# 5   0.348230
# 6   0.350597
# 7   0.959877
# 8   0.400834
# 9   1.164253
# 10  0.537223
# 11  0.444758
# 12  0.273073
# 13  0.317825
# 14  0.298326
# 15  0.366022
# 16  0.726712
# 17  0.722590
# 18  0.610729
# 19  0.995984
# 20  0.265619
# 21  1.364557
# 22  0.346969

# %%
directory = os.path.join(os.getcwd(), 'backpack\\testing')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        try:
            testOriginal = pd.read_csv(filepath)
            test=testOriginal.copy()

            num_rows_before = test.shape[0]

            fivePercent = num_rows_before * 0.1
            fivePercent = math.ceil(fivePercent)

            #test = test.iloc[fivePercent:]
            #test = test.iloc[:-fivePercent]


            num_rows = test.shape[0]
            start_row = 0
            end_row = num_rows/2
            end_row = math.ceil(end_row)
            print(end_row)   
            # Create a new row of data
            new_row = [filepath[53:67],test['LA(x)'][start_row:end_row].mean(),test['LA(y)'][start_row:end_row].mean(),test['LA(z)'][start_row:end_row].mean(),test['GY(x)'][start_row:end_row].mean(),test['GY(y)'][start_row:end_row].mean(),test['GY(z)'][start_row:end_row].mean(),test['LA(x)'][start_row:end_row].std(),test['LA(y)'][start_row:end_row].std(),test['LA(z)'][start_row:end_row].std(),test['GY(x)'][start_row:end_row].std(),test['GY(y)'][start_row:end_row].std(),test['GY(z)'][start_row:end_row].std()]

            # Add the new row to the DataFrame
            df.loc[len(df)] = new_row
        except Exception as e:
            print(f"Error occurred while reading file: {filename}")
            print(f"Error message: {str(e)}")
            continue
# Out:
# 7404
# 7805
# 6927
# 6399
# 46495
# 7687
# 7172
# 6908
# 8488

# %%
df
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0   damirBackpack.    0.173140   -0.362729   -0.304252    0.031552
# 1   udBackpack.csv    0.185752    0.174124   -0.336641   -0.022657
# 2   xBackpackx150x    0.374895    0.067851    0.649481    0.077865
# 3   hxBackpackx726    0.178686   -0.166713    0.475920    0.014834
# 4   alyBackpack.cs    0.111783   -0.433144   -0.417921   -0.017812
# 5   batarabayBackp    0.208458   -0.141582   -0.160986   -0.006641
# 6   nabulxBackpack    0.224665    0.084392    0.432724    0.059310
# 7   emdakrouryxBac   -0.050529   -0.550069    0.530442    0.025622
# 8    iBackpack.csv    0.608332   -0.438298    0.809968   -0.109700
# 9   anyBackpack.cs    0.464066   -0.516951   -0.437352    0.024444
# 10  ilBackpack.csv   -0.080248   -0.473817   -0.651985   -0.056057
# 11   hBackpack.csv    0.018211   -0.084585    0.246519   -0.089954
# 12    Backpack.csv    0.032419   -0.048211    0.278499   -0.033532
# 13  nxBackpackx727    0.060843   -0.118921    0.291233   -0.000720
# 14  rahmedxBackpac    0.080295   -0.033566    0.519944    0.127773
# 15    Backpack.csv    0.260765   -0.039654    0.515398    0.035173
# 16  aztarekBackpac    0.194859   -0.412887    0.644415    0.236098
# 17  medDawodBackpa    0.177092    0.101428    0.575278   -0.025953
# 18  medelshouraBac    0.048796   -0.325339    0.652739   -0.021387
# 19  mmddBackpack.c   -0.073835   -0.631035    0.409352    0.002620
# 20  han2Backpack.c   -0.036326   -0.067695    0.347675   -0.160543
# 21     ackpack.csv    0.051690   -0.287569    0.267416   -0.011164
# 22    Backpack.csv    0.166638    0.035656    0.357881   -0.007260
# 23  waBackpack.csv    0.182021   -0.011097    0.460714    0.191014
# 24  fanaBackpack.c   -0.249864   -0.544908   -0.580775    0.053012
# 25  fzakriaxBackpa    0.318233   -0.735143    0.927464    0.112910
# 26  hyeBackpack.cs   -0.123444   -0.605728    0.588243    0.048165
# 27  dhatemxBackpac    0.104491   -0.120244   -0.082177    0.025516
# 28  sinriafBackpac    0.238989   -0.457418    0.567982    0.028717
# 29  ssefBackpack.c    0.150874   -0.544265   -0.543091   -0.142702
# 30  ssefemadxBackp    0.192784   -0.213784   -0.322340   -0.125805
# 31  ufBackpack.csv    0.074860    0.222392    0.582544    0.114855
#
#     mean_GY(y)  mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  \
# 0    -0.237884    0.083588  2.859100  2.867278  3.826793  1.097045  0.777185
# 1     0.093827    0.091212  1.494032  2.540328  1.943992  1.164921  1.167235
# 2    -0.489211   -0.037927  1.756166  3.771635  2.815990  0.718165  1.428170
# 3    -0.150377   -0.018530  2.676458  2.077343  2.267622  0.583846  1.297955
# 4    -0.400863    0.090023  3.318476  3.356504  3.908902  1.198260  1.358760
# 5    -0.150630    0.035445  1.638030  1.883974  1.473826  0.552574  0.938636
# 6    -0.395847    0.039624  1.838944  2.292370  1.724860  0.485338  1.135749
# 7     0.190021   -0.054816  3.791056  3.102421  3.623300  1.211993  1.196973
# 8    -0.597485   -0.129551  2.586825  3.274957  3.083887  1.036623  1.142425
# 9    -0.404135    0.095487  4.266029  4.227338  4.495964  1.152665  1.363092
# 10   -0.440621    0.114939  3.303495  3.082101  4.343135  1.183130  1.689904
# 11    0.495236    0.089475  1.851759  2.234073  1.588229  0.423044  0.908659
# 12    0.171618   -0.004188  1.313335  2.139008  1.569074  0.369310  1.009167
# 13    0.486094    0.050412  2.050625  2.078332  2.057279  0.660661  0.907377
# 14   -0.395082   -0.063546  1.529137  1.869428  1.492061  0.524531  0.877886
# 15   -0.547417   -0.017539  1.448708  1.959189  1.546230  0.610491  1.139611
# 16   -0.392229   -0.097366  3.837957  2.096841  3.870308  0.997571  1.462269
# 17   -0.233091   -0.086481  1.614310  2.800086  2.219401  1.163054  1.269114
# 18   -0.442043   -0.097110  2.185065  2.774451  2.843697  1.020901  1.058725
# 19    0.100124   -0.017143  5.374921  3.617437  4.620766  1.104431  1.424394
# 20    0.412989    0.010776  1.227084  1.601409  1.861783  0.480421  0.760038
# 21    0.181223   -0.015049  4.266359  1.932189  1.810843  0.605887  1.288164
# 22   -0.146467    0.029661  1.387525  1.661000  1.391092  0.410860  1.071594
# 23   -0.478595   -0.007603  1.450011  1.999993  1.454446  0.552448  0.877880
# 24   -0.416784    0.174799  2.916957  3.658622  4.529438  1.507712  1.379992
# 25   -0.473986   -0.151236  4.755181  5.280667  5.995603  1.360136  1.543514
# 26    0.072302   -0.007153  3.268385  4.218153  5.473271  1.569168  1.737715
# 27    0.027050   -0.033200  1.557753  1.492255  1.733548  0.663982  0.928513
# 28    0.002257   -0.045409  2.961146  2.926309  4.764953  1.252251  1.449122
# 29   -0.482841    0.175048  3.555273  3.245579  4.969826  1.334969  1.647257
# 30    0.509473    0.015595  2.455788  2.720039  3.322870  1.098000  1.225044
# 31    0.400765   -0.027688  1.895362  2.720744  3.261370  1.375514  1.879687
#
#     sd_GY(z)
# 0   0.659330
# 1   0.520876
# 2   0.424324
# 3   0.659447
# 4   0.613796
# 5   0.348230
# 6   0.350597
# 7   0.959877
# 8   0.400834
# 9   1.164253
# 10  0.537223
# 11  0.444758
# 12  0.273073
# 13  0.317825
# 14  0.298326
# 15  0.366022
# 16  0.726712
# 17  0.722590
# 18  0.610729
# 19  0.995984
# 20  0.265619
# 21  1.364557
# 22  0.346969
# 23  0.261252
# 24  0.598623
# 25  0.925896
# 26  0.683510
# 27  0.547090
# 28  0.516393
# 29  0.738860
# 30  0.392530
# 31  0.557348

# %%
label_column = 'name'
label_encoder = LabelEncoder()
df[label_column] = label_encoder.fit_transform(df[label_column])

# %%
df
# Out:
#     name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0      6    0.173140   -0.362729   -0.304252    0.031552   -0.237884
# 1     26    0.185752    0.174124   -0.336641   -0.022657    0.093827
# 2     29    0.374895    0.067851    0.649481    0.077865   -0.489211
# 3     13    0.178686   -0.166713    0.475920    0.014834   -0.150377
# 4      2    0.111783   -0.433144   -0.417921   -0.017812   -0.400863
# 5      5    0.208458   -0.141582   -0.160986   -0.006641   -0.150630
# 6     20    0.224665    0.084392    0.432724    0.059310   -0.395847
# 7      8   -0.050529   -0.550069    0.530442    0.025622    0.190021
# 8     15    0.608332   -0.438298    0.809968   -0.109700   -0.597485
# 9      3    0.464066   -0.516951   -0.437352    0.024444   -0.404135
# 10    16   -0.080248   -0.473817   -0.651985   -0.056057   -0.440621
# 11    11    0.018211   -0.084585    0.246519   -0.089954    0.495236
# 12     0    0.032419   -0.048211    0.278499   -0.033532    0.171618
# 13    21    0.060843   -0.118921    0.291233   -0.000720    0.486094
# 14    22    0.080295   -0.033566    0.519944    0.127773   -0.395082
# 15     0    0.260765   -0.039654    0.515398    0.035173   -0.547417
# 16     4    0.194859   -0.412887    0.644415    0.236098   -0.392229
# 17    17    0.177092    0.101428    0.575278   -0.025953   -0.233091
# 18    18    0.048796   -0.325339    0.652739   -0.021387   -0.442043
# 19    19   -0.073835   -0.631035    0.409352    0.002620    0.100124
# 20    12   -0.036326   -0.067695    0.347675   -0.160543    0.412989
# 21     1    0.051690   -0.287569    0.267416   -0.011164    0.181223
# 22     0    0.166638    0.035656    0.357881   -0.007260   -0.146467
# 23    28    0.182021   -0.011097    0.460714    0.191014   -0.478595
# 24     9   -0.249864   -0.544908   -0.580775    0.053012   -0.416784
# 25    10    0.318233   -0.735143    0.927464    0.112910   -0.473986
# 26    14   -0.123444   -0.605728    0.588243    0.048165    0.072302
# 27     7    0.104491   -0.120244   -0.082177    0.025516    0.027050
# 28    23    0.238989   -0.457418    0.567982    0.028717    0.002257
# 29    24    0.150874   -0.544265   -0.543091   -0.142702   -0.482841
# 30    25    0.192784   -0.213784   -0.322340   -0.125805    0.509473
# 31    27    0.074860    0.222392    0.582544    0.114855    0.400765
#
#     mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0     0.083588  2.859100  2.867278  3.826793  1.097045  0.777185  0.659330
# 1     0.091212  1.494032  2.540328  1.943992  1.164921  1.167235  0.520876
# 2    -0.037927  1.756166  3.771635  2.815990  0.718165  1.428170  0.424324
# 3    -0.018530  2.676458  2.077343  2.267622  0.583846  1.297955  0.659447
# 4     0.090023  3.318476  3.356504  3.908902  1.198260  1.358760  0.613796
# 5     0.035445  1.638030  1.883974  1.473826  0.552574  0.938636  0.348230
# 6     0.039624  1.838944  2.292370  1.724860  0.485338  1.135749  0.350597
# 7    -0.054816  3.791056  3.102421  3.623300  1.211993  1.196973  0.959877
# 8    -0.129551  2.586825  3.274957  3.083887  1.036623  1.142425  0.400834
# 9     0.095487  4.266029  4.227338  4.495964  1.152665  1.363092  1.164253
# 10    0.114939  3.303495  3.082101  4.343135  1.183130  1.689904  0.537223
# 11    0.089475  1.851759  2.234073  1.588229  0.423044  0.908659  0.444758
# 12   -0.004188  1.313335  2.139008  1.569074  0.369310  1.009167  0.273073
# 13    0.050412  2.050625  2.078332  2.057279  0.660661  0.907377  0.317825
# 14   -0.063546  1.529137  1.869428  1.492061  0.524531  0.877886  0.298326
# 15   -0.017539  1.448708  1.959189  1.546230  0.610491  1.139611  0.366022
# 16   -0.097366  3.837957  2.096841  3.870308  0.997571  1.462269  0.726712
# 17   -0.086481  1.614310  2.800086  2.219401  1.163054  1.269114  0.722590
# 18   -0.097110  2.185065  2.774451  2.843697  1.020901  1.058725  0.610729
# 19   -0.017143  5.374921  3.617437  4.620766  1.104431  1.424394  0.995984
# 20    0.010776  1.227084  1.601409  1.861783  0.480421  0.760038  0.265619
# 21   -0.015049  4.266359  1.932189  1.810843  0.605887  1.288164  1.364557
# 22    0.029661  1.387525  1.661000  1.391092  0.410860  1.071594  0.346969
# 23   -0.007603  1.450011  1.999993  1.454446  0.552448  0.877880  0.261252
# 24    0.174799  2.916957  3.658622  4.529438  1.507712  1.379992  0.598623
# 25   -0.151236  4.755181  5.280667  5.995603  1.360136  1.543514  0.925896
# 26   -0.007153  3.268385  4.218153  5.473271  1.569168  1.737715  0.683510
# 27   -0.033200  1.557753  1.492255  1.733548  0.663982  0.928513  0.547090
# 28   -0.045409  2.961146  2.926309  4.764953  1.252251  1.449122  0.516393
# 29    0.175048  3.555273  3.245579  4.969826  1.334969  1.647257  0.738860
# 30    0.015595  2.455788  2.720039  3.322870  1.098000  1.225044  0.392530
# 31   -0.027688  1.895362  2.720744  3.261370  1.375514  1.879687  0.557348

# %%
df_testingHalf = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])
directory = os.path.join(os.getcwd(), 'backpack\\testing')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        try:
            testOriginal = pd.read_csv(filepath)
            test=testOriginal.copy()

            #         num_rows = test.shape[0]
            #         start_row = 0
            #         end_row = num_rows/2
            #         end_row = math.ceil(end_row)
            num_rows_before = test.shape[0]

            fivePercent = num_rows_before * 0.20
            fivePercent = math.ceil(fivePercent)

            #test = test.iloc[fivePercent:]
            test = test.iloc[:-fivePercent]

            num_rows = test.shape[0]


            end_row_init = num_rows/2
            end_row_init = math.ceil(end_row_init)

            start_row = end_row_init
            end_row=num_rows+1


            print(fivePercent)   
            # Create a new row of data
            new_row = [filepath[53:67],test['LA(x)'][start_row:end_row].mean(),test['LA(y)'][start_row:end_row].mean(),test['LA(z)'][start_row:end_row].mean(),test['GY(x)'][start_row:end_row].mean(),test['GY(y)'][start_row:end_row].mean(),test['GY(z)'][start_row:end_row].mean(),test['LA(x)'][start_row:end_row].std(),test['LA(y)'][start_row:end_row].std(),test['LA(z)'][start_row:end_row].std(),test['GY(x)'][start_row:end_row].std(),test['GY(y)'][start_row:end_row].std(),test['GY(z)'][start_row:end_row].std()]

            # Add the new row to the DataFrame
            df_testingHalf.loc[len(df_testingHalf)] = new_row
        except Exception as e:
            print(f"Error occurred while reading file: {filename}")
            print(f"Error message: {str(e)}")
            continue
# Out:
# 2962
# 3122
# 2771
# 2560
# 18598
# 3075
# 2869
# 2763
# 3395

# %%
df_testingHalf
# Out:
#              name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0  waBackpack.csv    0.141565   -0.120317    0.574348    0.233707   -0.588093
# 1  fanaBackpack.c   -0.192604   -0.575602   -0.582802   -0.000246   -0.095230
# 2  fzakriaxBackpa    0.389626   -0.937606    1.182028    0.048056   -0.652031
# 3  hyeBackpack.cs    0.015048   -0.918167    0.936313   -0.485603   -0.500242
# 4  dhatemxBackpac    0.028507   -0.029653   -0.024865    0.014505    0.032078
# 5  sinriafBackpac    0.234241   -0.540141    0.596178   -0.055729    0.057811
# 6  ssefBackpack.c    0.041981   -0.613675   -0.508868   -0.123220   -0.615267
# 7  ssefemadxBackp   -0.030774   -0.312918   -0.099697   -0.018910   -0.175196
# 8  ufBackpack.csv    0.059095    0.352030    0.668794    0.105693    0.523796
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0   -0.012014  1.477692  1.979376  1.386131  0.614115  0.864694  0.289253
# 1    0.153993  2.941068  4.111913  4.808887  1.564010  1.624470  0.631137
# 2   -0.196945  5.294291  5.381882  6.491918  1.453882  1.695892  1.068650
# 3   -0.068062  3.120465  3.970199  5.816313  1.609992  1.865667  0.717954
# 4   -0.014179  1.095588  0.983026  1.310857  0.371798  0.414065  0.303484
# 5   -0.015315  2.863483  2.645426  4.396047  1.301398  1.425624  0.539475
# 6    0.154319  3.776181  3.496727  5.318091  1.383297  1.695578  0.780143
# 7    0.113426  2.303168  2.616878  3.273348  1.099600  1.290172  0.354780
# 8   -0.010750  2.035583  2.796754  3.696025  1.444614  2.076034  0.614649

# %%
label_column = 'name'
label_encoder = LabelEncoder()
df[label_column] = label_encoder.fit_transform(df[label_column])

# %%
df
# Out:
#     name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0      6    0.173140   -0.362729   -0.304252    0.031552   -0.237884
# 1     26    0.185752    0.174124   -0.336641   -0.022657    0.093827
# 2     29    0.374895    0.067851    0.649481    0.077865   -0.489211
# 3     13    0.178686   -0.166713    0.475920    0.014834   -0.150377
# 4      2    0.111783   -0.433144   -0.417921   -0.017812   -0.400863
# 5      5    0.208458   -0.141582   -0.160986   -0.006641   -0.150630
# 6     20    0.224665    0.084392    0.432724    0.059310   -0.395847
# 7      8   -0.050529   -0.550069    0.530442    0.025622    0.190021
# 8     15    0.608332   -0.438298    0.809968   -0.109700   -0.597485
# 9      3    0.464066   -0.516951   -0.437352    0.024444   -0.404135
# 10    16   -0.080248   -0.473817   -0.651985   -0.056057   -0.440621
# 11    11    0.018211   -0.084585    0.246519   -0.089954    0.495236
# 12     0    0.032419   -0.048211    0.278499   -0.033532    0.171618
# 13    21    0.060843   -0.118921    0.291233   -0.000720    0.486094
# 14    22    0.080295   -0.033566    0.519944    0.127773   -0.395082
# 15     0    0.260765   -0.039654    0.515398    0.035173   -0.547417
# 16     4    0.194859   -0.412887    0.644415    0.236098   -0.392229
# 17    17    0.177092    0.101428    0.575278   -0.025953   -0.233091
# 18    18    0.048796   -0.325339    0.652739   -0.021387   -0.442043
# 19    19   -0.073835   -0.631035    0.409352    0.002620    0.100124
# 20    12   -0.036326   -0.067695    0.347675   -0.160543    0.412989
# 21     1    0.051690   -0.287569    0.267416   -0.011164    0.181223
# 22     0    0.166638    0.035656    0.357881   -0.007260   -0.146467
# 23    28    0.182021   -0.011097    0.460714    0.191014   -0.478595
# 24     9   -0.249864   -0.544908   -0.580775    0.053012   -0.416784
# 25    10    0.318233   -0.735143    0.927464    0.112910   -0.473986
# 26    14   -0.123444   -0.605728    0.588243    0.048165    0.072302
# 27     7    0.104491   -0.120244   -0.082177    0.025516    0.027050
# 28    23    0.238989   -0.457418    0.567982    0.028717    0.002257
# 29    24    0.150874   -0.544265   -0.543091   -0.142702   -0.482841
# 30    25    0.192784   -0.213784   -0.322340   -0.125805    0.509473
# 31    27    0.074860    0.222392    0.582544    0.114855    0.400765
#
#     mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0     0.083588  2.859100  2.867278  3.826793  1.097045  0.777185  0.659330
# 1     0.091212  1.494032  2.540328  1.943992  1.164921  1.167235  0.520876
# 2    -0.037927  1.756166  3.771635  2.815990  0.718165  1.428170  0.424324
# 3    -0.018530  2.676458  2.077343  2.267622  0.583846  1.297955  0.659447
# 4     0.090023  3.318476  3.356504  3.908902  1.198260  1.358760  0.613796
# 5     0.035445  1.638030  1.883974  1.473826  0.552574  0.938636  0.348230
# 6     0.039624  1.838944  2.292370  1.724860  0.485338  1.135749  0.350597
# 7    -0.054816  3.791056  3.102421  3.623300  1.211993  1.196973  0.959877
# 8    -0.129551  2.586825  3.274957  3.083887  1.036623  1.142425  0.400834
# 9     0.095487  4.266029  4.227338  4.495964  1.152665  1.363092  1.164253
# 10    0.114939  3.303495  3.082101  4.343135  1.183130  1.689904  0.537223
# 11    0.089475  1.851759  2.234073  1.588229  0.423044  0.908659  0.444758
# 12   -0.004188  1.313335  2.139008  1.569074  0.369310  1.009167  0.273073
# 13    0.050412  2.050625  2.078332  2.057279  0.660661  0.907377  0.317825
# 14   -0.063546  1.529137  1.869428  1.492061  0.524531  0.877886  0.298326
# 15   -0.017539  1.448708  1.959189  1.546230  0.610491  1.139611  0.366022
# 16   -0.097366  3.837957  2.096841  3.870308  0.997571  1.462269  0.726712
# 17   -0.086481  1.614310  2.800086  2.219401  1.163054  1.269114  0.722590
# 18   -0.097110  2.185065  2.774451  2.843697  1.020901  1.058725  0.610729
# 19   -0.017143  5.374921  3.617437  4.620766  1.104431  1.424394  0.995984
# 20    0.010776  1.227084  1.601409  1.861783  0.480421  0.760038  0.265619
# 21   -0.015049  4.266359  1.932189  1.810843  0.605887  1.288164  1.364557
# 22    0.029661  1.387525  1.661000  1.391092  0.410860  1.071594  0.346969
# 23   -0.007603  1.450011  1.999993  1.454446  0.552448  0.877880  0.261252
# 24    0.174799  2.916957  3.658622  4.529438  1.507712  1.379992  0.598623
# 25   -0.151236  4.755181  5.280667  5.995603  1.360136  1.543514  0.925896
# 26   -0.007153  3.268385  4.218153  5.473271  1.569168  1.737715  0.683510
# 27   -0.033200  1.557753  1.492255  1.733548  0.663982  0.928513  0.547090
# 28   -0.045409  2.961146  2.926309  4.764953  1.252251  1.449122  0.516393
# 29    0.175048  3.555273  3.245579  4.969826  1.334969  1.647257  0.738860
# 30    0.015595  2.455788  2.720039  3.322870  1.098000  1.225044  0.392530
# 31   -0.027688  1.895362  2.720744  3.261370  1.375514  1.879687  0.557348

# %%
encodedNames = df.loc[23:, 'name'].values
print(encodedNames)
# Out:
# [28  9 10 14  7 23 24 25 27]

# %%
df_testingHalf['name'] = encodedNames
df_testingHalf
# Out:
#    name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0    28    0.141565   -0.120317    0.574348    0.233707   -0.588093
# 1     9   -0.192604   -0.575602   -0.582802   -0.000246   -0.095230
# 2    10    0.389626   -0.937606    1.182028    0.048056   -0.652031
# 3    14    0.015048   -0.918167    0.936313   -0.485603   -0.500242
# 4     7    0.028507   -0.029653   -0.024865    0.014505    0.032078
# 5    23    0.234241   -0.540141    0.596178   -0.055729    0.057811
# 6    24    0.041981   -0.613675   -0.508868   -0.123220   -0.615267
# 7    25   -0.030774   -0.312918   -0.099697   -0.018910   -0.175196
# 8    27    0.059095    0.352030    0.668794    0.105693    0.523796
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0   -0.012014  1.477692  1.979376  1.386131  0.614115  0.864694  0.289253
# 1    0.153993  2.941068  4.111913  4.808887  1.564010  1.624470  0.631137
# 2   -0.196945  5.294291  5.381882  6.491918  1.453882  1.695892  1.068650
# 3   -0.068062  3.120465  3.970199  5.816313  1.609992  1.865667  0.717954
# 4   -0.014179  1.095588  0.983026  1.310857  0.371798  0.414065  0.303484
# 5   -0.015315  2.863483  2.645426  4.396047  1.301398  1.425624  0.539475
# 6    0.154319  3.776181  3.496727  5.318091  1.383297  1.695578  0.780143
# 7    0.113426  2.303168  2.616878  3.273348  1.099600  1.290172  0.354780
# 8   -0.010750  2.035583  2.796754  3.696025  1.444614  2.076034  0.614649

# %%
y_training_labels = df.pop('name')
y_training_labels
# Out:
# 0      6
# 1     26
# 2     29
# 3     13
# 4      2
# 5      5
# 6     20
# 7      8
# 8     15
# 9      3
# 10    16
# 11    11
# 12     0
# 13    21
# 14    22
# 15     0
# 16     4
# 17    17
# 18    18
# 19    19
# 20    12
# 21     1
# 22     0
# 23    28
# 24     9
# 25    10
# 26    14
# 27     7
# 28    23
# 29    24
# 30    25
# 31    27
# Name: name, dtype: int64

# %%
X_training_dataset = df.copy()

# %%
X_testing_dataset = df_testingHalf.copy()

# %%
y_testing_labels = X_testing_dataset.pop('name')

# %%
X_training_dataset.shape
# Out:
# (32, 12)

# %%
y_training_labels.shape
# Out:
# (32,)

# %%
X_testing_dataset.shape
# Out:
# (9, 12)

# %%
y_testing_labels.shape
# Out:
# (9,)

# %%
classifier = svm.SVC(kernel='linear', gamma='auto', C=2)

classifier.fit(X_training_dataset,y_training_labels)

y_testing_predict = classifier.predict(X_testing_dataset)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_testing_labels,y_testing_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         1
#            9       1.00      1.00      1.00         1
#           10       1.00      1.00      1.00         1
#           14       1.00      1.00      1.00         1
#           23       1.00      1.00      1.00         1
#           24       1.00      1.00      1.00         1
#           25       1.00      1.00      1.00         1
#           27       1.00      1.00      1.00         1
#           28       0.00      0.00      0.00         1
#
#     accuracy                           0.78         9
#    macro avg       0.70      0.70      0.70         9
# weighted avg       0.78      0.78      0.78         9
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Create a svm Classifier
model = svm.SVC(C = 9, # reg paramater
                kernel='linear', #kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
               ) # Linear Kernel

#Train the model using the training sets
model.fit(X_training_dataset, y_training_labels)

#Predict the response for test dataset
y_pred = model.predict(X_testing_dataset)

from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import metrics
y_pred = model.predict(X_training_dataset)
print("Accuracy:",metrics.accuracy_score(y_training_labels, y_pred))
# Out:
# Accuracy: 0.9375

# %%
from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
# Out:
# Accuracy: 1.0
