# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import seaborn as sns # for plotting.
import os
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])

# %%
directory = os.path.join(os.getcwd(), 'straightWalk')
x=1
firstTime = True
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        testOriginal = pd.read_csv(filepath)
        test=testOriginal.copy()
        # Create a new row of data
        new_row = [filepath[46:60],test['LA(x)'].mean(),test['LA(y)'].mean(),test['LA(z)'].mean(),test['GY(x)'].mean(),test['GY(y)'].mean(),test['GY(z)'].mean(),test['LA(x)'].std(),test['LA(y)'].std(),test['LA(z)'].std(),test['GY(x)'].std(),test['GY(y)'].std(),test['GY(z)'].std()]

        # Add the new row to the DataFrame
        df.loc[len(df)] = new_row

# %%
print(df)
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0   alibadawixStra    0.021361   -0.492503    0.570440    0.071714
# 1   dinaelgendyxSt    0.227064    0.077312    0.562713    0.007784
# 2   farahxStraight    0.106776   -0.202852    0.336103    0.009316
# 3   ghazalyStraigh    0.199047   -0.376709   -0.277852    0.070494
# 4   habibatarabayS    0.259229   -0.118446   -0.035600    0.044112
# 5   hananabilxStra    0.118827    0.031905   -0.080278   -0.016580
# 6   hashemdakroury    0.100317   -0.638231    0.779516    0.069368
# 7   heidiStraightW    0.416585   -0.374331    0.574468    0.035432
# 8   hoshantStraigh    0.400480   -0.583705   -0.565326    0.145026
# 9   ismail2Straigh    0.302428   -0.454693    0.876858   -0.002075
# 10  janahStraightW    0.360441   -0.303924    0.248520    0.083990
# 11  janqhStraightW    0.098203   -0.235560    0.251350   -0.045700
# 12  KarenxStraight    0.207348   -0.123532    0.306170   -0.000423
# ...

# %%
df.to_csv('newStatistical.csv', index=False)
