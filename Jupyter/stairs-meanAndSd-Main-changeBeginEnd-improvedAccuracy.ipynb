# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import seaborn as sns # for plotting.
import os
import math

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])

# %%
directory = os.path.join(os.getcwd(), 'stairs\\training')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        try:
            testOriginal = pd.read_csv(filepath)
            test=testOriginal.copy()
            num_rows_before = test.shape[0]

            fivePercent = num_rows_before * 0.20
            fivePercent = math.ceil(fivePercent)

            #test = test.iloc[fivePercent:]
            
            
            test = test.iloc[:-fivePercent]

            num_rows = test.shape[0]
            # Create a new row of data
            new_row = [filepath[55:69],test['LA(x)'].mean(),test['LA(y)'].mean(),test['LA(z)'].mean(),test['GY(x)'].mean(),test['GY(y)'].mean(),test['GY(z)'].mean(),test['LA(x)'].std(),test['LA(y)'].std(),test['LA(z)'].std(),test['GY(x)'].std(),test['GY(y)'].std(),test['GY(z)'].std()]

            # Add the new row to the DataFrame
            df.loc[len(df)] = new_row
        except Exception as e:
            print(f"Error occurred while reading file: {filename}")
            print(f"Error message: {str(e)}")
            continue

# %%
df
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0    mirStairs.csv    0.144788   -0.377471    0.464804   -0.017433
# 1   tairsxhabsgxhs    0.128859   -0.463654    0.412851    0.095233
# 2       Stairs.csv    0.077478    0.151078   -0.143524   -0.017665
# 3   Stairsx7263x72    0.034107    0.037947    0.364967   -0.034809
# 4     22Stairs.csv    0.056457   -0.542300   -0.373110    0.018970
# 5   tarabayStairs.    0.289920   -0.162950   -0.061525    0.096943
# 6        tairs.csv    0.388829   -0.289750    0.285754   -0.048352
# 7    222Stairs.csv    0.112678   -0.854486    0.324565   -0.070992
# 8          irs.csv    0.346090   -0.886796   -0.790666    0.032929
# 9       Stairs.csv   -0.013824   -0.742119    0.657354   -0.213703
# 10    ddStairs.csv    0.133007   -0.659408    0.380883    0.030004
#
#     mean_GY(y)  mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  \
# 0     0.285268   -0.010918  2.640668  4.157759  3.107656  1.274574  0.953644
# 1    -0.092352   -0.061233  3.081139  2.997142  3.150151  1.171772  1.389636
# 2    -0.356267    0.001658  1.487001  3.127533  1.854058  1.288109  1.054342
# 3     0.153193   -0.014635  2.369922  5.076737  2.436780  0.742355  1.159667
# 4    -0.062441    0.078783  2.640989  4.142151  3.866938  1.786486  1.198987
# 5     0.428370   -0.041354  1.633703  3.305095  1.901927  0.635609  0.898373
# 6    -0.147996   -0.070289  3.335023  5.804150  2.725376  1.232113  1.340347
# 7     0.503023   -0.026524  4.903765  5.361202  4.765900  1.398531  1.615541
# 8    -0.506648    0.152410  4.485690  5.175227  5.456269  1.740473  1.694929
# 9    -0.340073   -0.095840  3.682009  3.546438  4.104852  1.236236  1.331345
# 10   -0.031982   -0.035666  4.744822  3.719602  3.367904  1.092839  1.294499
#
#     sd_GY(z)
# 0   0.476125
# 1   1.015041
# 2   0.422771
# 3   0.373950
# 4   0.480055
# 5   0.350286
# 6   0.705779
# 7   1.258626
# 8   1.386420
# 9   0.911038
# 10  1.228670

# %%
directory = os.path.join(os.getcwd(), 'stairs\\testing')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        try:
            testOriginal = pd.read_csv(filepath)
            test=testOriginal.copy()

            num_rows_before = test.shape[0]

            fivePercent = num_rows_before * 0.2
            fivePercent = math.ceil(fivePercent)

            #test = test.iloc[fivePercent:]
            #test = test.iloc[:-fivePercent]


            num_rows = test.shape[0]
            start_row = 0
            end_row = num_rows/2
            end_row = math.ceil(end_row)
            print(end_row)   
            # Create a new row of data
            new_row = [filepath[53:67],test['LA(x)'][start_row:end_row].mean(),test['LA(y)'][start_row:end_row].mean(),test['LA(z)'][start_row:end_row].mean(),test['GY(x)'][start_row:end_row].mean(),test['GY(y)'][start_row:end_row].mean(),test['GY(z)'][start_row:end_row].mean(),test['LA(x)'][start_row:end_row].std(),test['LA(y)'][start_row:end_row].std(),test['LA(z)'][start_row:end_row].std(),test['GY(x)'][start_row:end_row].std(),test['GY(y)'][start_row:end_row].std(),test['GY(z)'][start_row:end_row].std()]

            # Add the new row to the DataFrame
            df.loc[len(df)] = new_row
        except Exception as e:
            print(f"Error occurred while reading file: {filename}")
            print(f"Error message: {str(e)}")
            continue
# Out:
# 9646
# 7683
# 8408
# 7844
# 7937
# 9135

# %%
df
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0    mirStairs.csv    0.144788   -0.377471    0.464804   -0.017433
# 1   tairsxhabsgxhs    0.128859   -0.463654    0.412851    0.095233
# 2       Stairs.csv    0.077478    0.151078   -0.143524   -0.017665
# 3   Stairsx7263x72    0.034107    0.037947    0.364967   -0.034809
# 4     22Stairs.csv    0.056457   -0.542300   -0.373110    0.018970
# 5   tarabayStairs.    0.289920   -0.162950   -0.061525    0.096943
# 6        tairs.csv    0.388829   -0.289750    0.285754   -0.048352
# 7    222Stairs.csv    0.112678   -0.854486    0.324565   -0.070992
# 8          irs.csv    0.346090   -0.886796   -0.790666    0.032929
# 9       Stairs.csv   -0.013824   -0.742119    0.657354   -0.213703
# 10    ddStairs.csv    0.133007   -0.659408    0.380883    0.030004
# 11    anStairs.csv    0.064457   -0.023400    0.296157   -0.025546
# 12    e3Stairs.csv    0.382522   -0.570196    0.614066    0.012704
# 13  nriadStairs.cs    0.443545   -0.691809    0.676733    0.011982
# 14  efemadxStairsx    0.136494   -0.413244   -0.376618   -0.000058
# 15    efStairs.csv    0.135281   -0.577080   -0.496914   -0.115490
# 16      Stairs.csv    0.212120    0.348983    0.711509    0.080817
#
#     mean_GY(y)  mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  \
# 0     0.285268   -0.010918  2.640668  4.157759  3.107656  1.274574  0.953644
# 1    -0.092352   -0.061233  3.081139  2.997142  3.150151  1.171772  1.389636
# 2    -0.356267    0.001658  1.487001  3.127533  1.854058  1.288109  1.054342
# 3     0.153193   -0.014635  2.369922  5.076737  2.436780  0.742355  1.159667
# 4    -0.062441    0.078783  2.640989  4.142151  3.866938  1.786486  1.198987
# 5     0.428370   -0.041354  1.633703  3.305095  1.901927  0.635609  0.898373
# 6    -0.147996   -0.070289  3.335023  5.804150  2.725376  1.232113  1.340347
# 7     0.503023   -0.026524  4.903765  5.361202  4.765900  1.398531  1.615541
# 8    -0.506648    0.152410  4.485690  5.175227  5.456269  1.740473  1.694929
# 9    -0.340073   -0.095840  3.682009  3.546438  4.104852  1.236236  1.331345
# 10   -0.031982   -0.035666  4.744822  3.719602  3.367904  1.092839  1.294499
# 11   -0.010121   -0.019074  1.372078  2.321932  1.292289  0.493809  0.797768
# 12   -0.033642   -0.045342  4.509614  4.419192  5.082644  1.212296  1.991386
# 13   -0.429023   -0.098963  3.474442  4.024979  4.671159  1.631462  1.616810
# 14    0.031774    0.031288  2.551615  4.655520  5.185730  1.545369  1.519426
# 15   -0.415962    0.112689  3.908257  4.262535  7.154133  1.455845  2.095633
# 16    0.334184   -0.006281  2.497458  4.623743  4.207350  1.671163  1.753486
#
#     sd_GY(z)
# 0   0.476125
# 1   1.015041
# 2   0.422771
# 3   0.373950
# 4   0.480055
# 5   0.350286
# 6   0.705779
# 7   1.258626
# 8   1.386420
# 9   0.911038
# 10  1.228670
# 11  0.269949
# 12  1.002634
# 13  0.652632
# 14  0.620595
# 15  0.929926
# 16  0.645833

# %%
label_column = 'name'
label_encoder = LabelEncoder()
df[label_column] = label_encoder.fit_transform(df[label_column])

# %%
df
# Out:
#     name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     10    0.144788   -0.377471    0.464804   -0.017433    0.285268
# 1     13    0.128859   -0.463654    0.412851    0.095233   -0.092352
# 2      2    0.077478    0.151078   -0.143524   -0.017665   -0.356267
# 3      3    0.034107    0.037947    0.364967   -0.034809    0.153193
# 4      1    0.056457   -0.542300   -0.373110    0.018970   -0.062441
# 5     14    0.289920   -0.162950   -0.061525    0.096943    0.428370
# 6     12    0.388829   -0.289750    0.285754   -0.048352   -0.147996
# 7      0    0.112678   -0.854486    0.324565   -0.070992    0.503023
# 8      9    0.346090   -0.886796   -0.790666    0.032929   -0.506648
# 9      2   -0.013824   -0.742119    0.657354   -0.213703   -0.340073
# 10     5    0.133007   -0.659408    0.380883    0.030004   -0.031982
# 11     4    0.064457   -0.023400    0.296157   -0.025546   -0.010121
# 12     6    0.382522   -0.570196    0.614066    0.012704   -0.033642
# 13    11    0.443545   -0.691809    0.676733    0.011982   -0.429023
# 14     8    0.136494   -0.413244   -0.376618   -0.000058    0.031774
# 15     7    0.135281   -0.577080   -0.496914   -0.115490   -0.415962
# 16     2    0.212120    0.348983    0.711509    0.080817    0.334184
#
#     mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0    -0.010918  2.640668  4.157759  3.107656  1.274574  0.953644  0.476125
# 1    -0.061233  3.081139  2.997142  3.150151  1.171772  1.389636  1.015041
# 2     0.001658  1.487001  3.127533  1.854058  1.288109  1.054342  0.422771
# 3    -0.014635  2.369922  5.076737  2.436780  0.742355  1.159667  0.373950
# 4     0.078783  2.640989  4.142151  3.866938  1.786486  1.198987  0.480055
# 5    -0.041354  1.633703  3.305095  1.901927  0.635609  0.898373  0.350286
# 6    -0.070289  3.335023  5.804150  2.725376  1.232113  1.340347  0.705779
# 7    -0.026524  4.903765  5.361202  4.765900  1.398531  1.615541  1.258626
# 8     0.152410  4.485690  5.175227  5.456269  1.740473  1.694929  1.386420
# 9    -0.095840  3.682009  3.546438  4.104852  1.236236  1.331345  0.911038
# 10   -0.035666  4.744822  3.719602  3.367904  1.092839  1.294499  1.228670
# 11   -0.019074  1.372078  2.321932  1.292289  0.493809  0.797768  0.269949
# 12   -0.045342  4.509614  4.419192  5.082644  1.212296  1.991386  1.002634
# 13   -0.098963  3.474442  4.024979  4.671159  1.631462  1.616810  0.652632
# 14    0.031288  2.551615  4.655520  5.185730  1.545369  1.519426  0.620595
# 15    0.112689  3.908257  4.262535  7.154133  1.455845  2.095633  0.929926
# 16   -0.006281  2.497458  4.623743  4.207350  1.671163  1.753486  0.645833

# %%
df_testingHalf = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])
directory = os.path.join(os.getcwd(), 'stairs\\testing')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        testOriginal = pd.read_csv(filepath)
        test=testOriginal.copy()
        
#         num_rows = test.shape[0]
#         start_row = 0
#         end_row = num_rows/2
#         end_row = math.ceil(end_row)
        num_rows_before = test.shape[0]
    
        fivePercent = num_rows_before * 0.20
        fivePercent = math.ceil(fivePercent)
        
        #test = test.iloc[fivePercent:]
        
        
        test = test.iloc[:-fivePercent]
        
        num_rows = test.shape[0]
        
    
        end_row_init = num_rows/2
        end_row_init = math.ceil(end_row_init)
        
        start_row = end_row_init
        end_row=num_rows+1
        
        
        print(fivePercent)   
        # Create a new row of data
        new_row = [filepath[53:67],test['LA(x)'][start_row:end_row].mean(),test['LA(y)'][start_row:end_row].mean(),test['LA(z)'][start_row:end_row].mean(),test['GY(x)'][start_row:end_row].mean(),test['GY(y)'][start_row:end_row].mean(),test['GY(z)'][start_row:end_row].mean(),test['LA(x)'][start_row:end_row].std(),test['LA(y)'][start_row:end_row].std(),test['LA(z)'][start_row:end_row].std(),test['GY(x)'][start_row:end_row].std(),test['GY(y)'][start_row:end_row].std(),test['GY(z)'][start_row:end_row].std()]

        # Add the new row to the DataFrame
        df_testingHalf.loc[len(df_testingHalf)] = new_row
# Out:
# 3859
# 3074
# 3363
# 3138
# 3175
# 3654

# %%
df_testingHalf
# Out:
#              name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0    anStairs.csv    0.158827   -0.007164    0.249851    0.079485   -0.136534
# 1    e3Stairs.csv    0.777677   -0.726352    0.589847   -0.023251    0.072720
# 2  nriadStairs.cs    0.420068   -0.729746    0.659450    0.006600   -0.418628
# 3  efemadxStairsx    0.190819   -0.437344   -0.378117   -0.049364    0.001348
# 4    efStairs.csv    0.193805   -0.678005   -0.478531   -0.116363   -0.513081
# 5      Stairs.csv    0.154599    0.395881    0.730906    0.176489    0.443364
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0   -0.025641  1.460902  2.223528  1.284463  0.544402  0.757279  0.288676
# 1   -0.075804  5.797640  6.632377  6.591896  1.432675  2.636261  1.249042
# 2   -0.087353  3.854589  4.076937  4.431242  1.626786  1.653985  0.723816
# 3    0.006441  3.143330  5.853462  5.462885  1.538780  1.630575  0.736170
# 4    0.110978  4.123934  4.634504  7.400129  1.499759  2.234951  0.881686
# 5    0.005335  2.530211  4.806776  4.371492  1.729400  1.906088  0.645355

# %%
# label_column = 'name'
# label_encoder = LabelEncoder()
# df[label_column] = label_encoder.fit_transform(df[label_column])

# %%
df
# Out:
#     name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     10    0.144788   -0.377471    0.464804   -0.017433    0.285268
# 1     13    0.128859   -0.463654    0.412851    0.095233   -0.092352
# 2      2    0.077478    0.151078   -0.143524   -0.017665   -0.356267
# 3      3    0.034107    0.037947    0.364967   -0.034809    0.153193
# 4      1    0.056457   -0.542300   -0.373110    0.018970   -0.062441
# 5     14    0.289920   -0.162950   -0.061525    0.096943    0.428370
# 6     12    0.388829   -0.289750    0.285754   -0.048352   -0.147996
# 7      0    0.112678   -0.854486    0.324565   -0.070992    0.503023
# 8      9    0.346090   -0.886796   -0.790666    0.032929   -0.506648
# 9      2   -0.013824   -0.742119    0.657354   -0.213703   -0.340073
# 10     5    0.133007   -0.659408    0.380883    0.030004   -0.031982
# 11     4    0.064457   -0.023400    0.296157   -0.025546   -0.010121
# 12     6    0.382522   -0.570196    0.614066    0.012704   -0.033642
# 13    11    0.443545   -0.691809    0.676733    0.011982   -0.429023
# 14     8    0.136494   -0.413244   -0.376618   -0.000058    0.031774
# 15     7    0.135281   -0.577080   -0.496914   -0.115490   -0.415962
# 16     2    0.212120    0.348983    0.711509    0.080817    0.334184
#
#     mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0    -0.010918  2.640668  4.157759  3.107656  1.274574  0.953644  0.476125
# 1    -0.061233  3.081139  2.997142  3.150151  1.171772  1.389636  1.015041
# 2     0.001658  1.487001  3.127533  1.854058  1.288109  1.054342  0.422771
# 3    -0.014635  2.369922  5.076737  2.436780  0.742355  1.159667  0.373950
# 4     0.078783  2.640989  4.142151  3.866938  1.786486  1.198987  0.480055
# 5    -0.041354  1.633703  3.305095  1.901927  0.635609  0.898373  0.350286
# 6    -0.070289  3.335023  5.804150  2.725376  1.232113  1.340347  0.705779
# 7    -0.026524  4.903765  5.361202  4.765900  1.398531  1.615541  1.258626
# 8     0.152410  4.485690  5.175227  5.456269  1.740473  1.694929  1.386420
# 9    -0.095840  3.682009  3.546438  4.104852  1.236236  1.331345  0.911038
# 10   -0.035666  4.744822  3.719602  3.367904  1.092839  1.294499  1.228670
# 11   -0.019074  1.372078  2.321932  1.292289  0.493809  0.797768  0.269949
# 12   -0.045342  4.509614  4.419192  5.082644  1.212296  1.991386  1.002634
# 13   -0.098963  3.474442  4.024979  4.671159  1.631462  1.616810  0.652632
# 14    0.031288  2.551615  4.655520  5.185730  1.545369  1.519426  0.620595
# 15    0.112689  3.908257  4.262535  7.154133  1.455845  2.095633  0.929926
# 16   -0.006281  2.497458  4.623743  4.207350  1.671163  1.753486  0.645833

# %%
df_testingHalf
# Out:
#              name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0    anStairs.csv    0.158827   -0.007164    0.249851    0.079485   -0.136534
# 1    e3Stairs.csv    0.777677   -0.726352    0.589847   -0.023251    0.072720
# 2  nriadStairs.cs    0.420068   -0.729746    0.659450    0.006600   -0.418628
# 3  efemadxStairsx    0.190819   -0.437344   -0.378117   -0.049364    0.001348
# 4    efStairs.csv    0.193805   -0.678005   -0.478531   -0.116363   -0.513081
# 5      Stairs.csv    0.154599    0.395881    0.730906    0.176489    0.443364
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0   -0.025641  1.460902  2.223528  1.284463  0.544402  0.757279  0.288676
# 1   -0.075804  5.797640  6.632377  6.591896  1.432675  2.636261  1.249042
# 2   -0.087353  3.854589  4.076937  4.431242  1.626786  1.653985  0.723816
# 3    0.006441  3.143330  5.853462  5.462885  1.538780  1.630575  0.736170
# 4    0.110978  4.123934  4.634504  7.400129  1.499759  2.234951  0.881686
# 5    0.005335  2.530211  4.806776  4.371492  1.729400  1.906088  0.645355

# %%
encodedNames = df.loc[11:, 'name'].values
print(encodedNames)
# Out:
# [ 4  6 11  8  7  2]

# %%
df_testingHalf['name'] = encodedNames
df_testingHalf
# Out:
#    name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     4    0.158827   -0.007164    0.249851    0.079485   -0.136534
# 1     6    0.777677   -0.726352    0.589847   -0.023251    0.072720
# 2    11    0.420068   -0.729746    0.659450    0.006600   -0.418628
# 3     8    0.190819   -0.437344   -0.378117   -0.049364    0.001348
# 4     7    0.193805   -0.678005   -0.478531   -0.116363   -0.513081
# 5     2    0.154599    0.395881    0.730906    0.176489    0.443364
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0   -0.025641  1.460902  2.223528  1.284463  0.544402  0.757279  0.288676
# 1   -0.075804  5.797640  6.632377  6.591896  1.432675  2.636261  1.249042
# 2   -0.087353  3.854589  4.076937  4.431242  1.626786  1.653985  0.723816
# 3    0.006441  3.143330  5.853462  5.462885  1.538780  1.630575  0.736170
# 4    0.110978  4.123934  4.634504  7.400129  1.499759  2.234951  0.881686
# 5    0.005335  2.530211  4.806776  4.371492  1.729400  1.906088  0.645355

# %%
y_training_labels = df.pop('name')
y_training_labels
# Out:
# 0     10
# 1     13
# 2      2
# 3      3
# 4      1
# 5     14
# 6     12
# 7      0
# 8      9
# 9      2
# 10     5
# 11     4
# 12     6
# 13    11
# 14     8
# 15     7
# 16     2
# Name: name, dtype: int32

# %%
X_training_dataset = df.copy()

# %%
X_testing_dataset = df_testingHalf.copy()

# %%
y_testing_labels = X_testing_dataset.pop('name')

# %%
X_training_dataset.shape
# Out:
# (17, 12)

# %%
y_training_labels.shape
# Out:
# (17,)

# %%
X_testing_dataset.shape
# Out:
# (6, 12)

# %%
y_testing_labels.shape
# Out:
# (6,)

# %%
classifier = svm.SVC(kernel='linear', gamma='auto', C=2)

classifier.fit(X_training_dataset,y_training_labels)

y_testing_predict = classifier.predict(X_testing_dataset)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_testing_labels,y_testing_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         1
#           11       1.00      1.00      1.00         1
#
#     accuracy                           0.83         6
#    macro avg       0.71      0.71      0.71         6
# weighted avg       0.83      0.83      0.83         6
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\szizo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Create a svm Classifier
model = svm.SVC(C = 2, # reg paramater
                kernel='linear', #kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
               ) # Linear Kernel

#Train the model using the training sets
model.fit(X_training_dataset, y_training_labels)

#Predict the response for test dataset
y_pred = model.predict(X_testing_dataset)

from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
# Out:
# Accuracy: 0.8333333333333334

# %%
from sklearn import metrics
y_pred = model.predict(X_training_dataset)
print("Accuracy:",metrics.accuracy_score(y_training_labels, y_pred))
# Out:
# Accuracy: 0.9411764705882353

# %%
from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
# Out:
# Accuracy: 0.8333333333333334
