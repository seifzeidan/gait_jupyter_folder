# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import seaborn as sns # for plotting.
import os
import math

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])

# %%
directory = os.path.join(os.getcwd(), 'straightWalk\\training')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        testOriginal = pd.read_csv(filepath)
        test=testOriginal.copy()
        
        
#         num_rows_before = test.shape[0]
    
#         fivePercent = num_rows_before * 0.15
#         fivePercent = math.ceil(fivePercent)
        
#         test = test.iloc[fivePercent:]
#         test = test.iloc[:-fivePercent]
        
        num_rows = test.shape[0]
        # Create a new row of data
        new_row = [filepath[55:69],test['LA(x)'].mean(),test['LA(y)'].mean(),test['LA(z)'].mean(),test['GY(x)'].mean(),test['GY(y)'].mean(),test['GY(z)'].mean(),test['LA(x)'].std(),test['LA(y)'].std(),test['LA(z)'].std(),test['GY(x)'].std(),test['GY(y)'].std(),test['GY(z)'].std()]

        # Add the new row to the DataFrame
        df.loc[len(df)] = new_row

# %%
df
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0   alibadawixStra    0.021361   -0.492503    0.570440    0.071714
# 1   dinaelgendyxSt    0.227064    0.077312    0.562713    0.007784
# 2   farahxStraight    0.106776   -0.202852    0.336103    0.009316
# 3   ghazalyStraigh    0.199047   -0.376709   -0.277852    0.070494
# 4   habibatarabayS    0.259229   -0.118446   -0.035600    0.044112
# 5   hananabilxStra    0.118827    0.031905   -0.080278   -0.016580
# 6   hashemdakroury    0.100317   -0.638231    0.779516    0.069368
# 7   heidiStraightW    0.416585   -0.374331    0.574468    0.035432
# 8   hoshantStraigh    0.400480   -0.583705   -0.565326    0.145026
# 9   ismail2Straigh    0.302428   -0.454693    0.876858   -0.002075
# 10  janahStraightW    0.360441   -0.303924    0.248520    0.083990
# 11  janqhStraightW    0.098203   -0.235560    0.251350   -0.045700
# 12  KarenxStraight    0.207348   -0.123532    0.306170   -0.000423
# ...

# %%
directory = os.path.join(os.getcwd(), 'straightWalk\\testing')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        testOriginal = pd.read_csv(filepath)
        test=testOriginal.copy()
        
#         num_rows_before = test.shape[0]
    
#         fivePercent = num_rows_before * 0.15
#         fivePercent = math.ceil(fivePercent)
        
#         test = test.iloc[fivePercent:]
        
        
        
        #test = test.iloc[:-fivePercent]
        
        
        num_rows = test.shape[0]
        start_row = 0
        end_row = num_rows/2
        end_row = math.ceil(end_row)
        print(end_row)   
        # Create a new row of data
        new_row = [filepath[53:67],test['LA(x)'][start_row:end_row].mean(),test['LA(y)'][start_row:end_row].mean(),test['LA(z)'][start_row:end_row].mean(),test['GY(x)'][start_row:end_row].mean(),test['GY(y)'][start_row:end_row].mean(),test['GY(z)'][start_row:end_row].mean(),test['LA(x)'][start_row:end_row].std(),test['LA(y)'][start_row:end_row].std(),test['LA(z)'][start_row:end_row].std(),test['GY(x)'][start_row:end_row].std(),test['GY(y)'][start_row:end_row].std(),test['GY(z)'][start_row:end_row].std()]

        # Add the new row to the DataFrame
        df.loc[len(df)] = new_row
# Out:
# 7553
# 6969
# 6716
# 8402
# 7419
# 6979
# 6452
# 8570
# 8016

# %%
df
# Out:
#               name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  \
# 0   alibadawixStra    0.021361   -0.492503    0.570440    0.071714
# 1   dinaelgendyxSt    0.227064    0.077312    0.562713    0.007784
# 2   farahxStraight    0.106776   -0.202852    0.336103    0.009316
# 3   ghazalyStraigh    0.199047   -0.376709   -0.277852    0.070494
# 4   habibatarabayS    0.259229   -0.118446   -0.035600    0.044112
# 5   hananabilxStra    0.118827    0.031905   -0.080278   -0.016580
# 6   hashemdakroury    0.100317   -0.638231    0.779516    0.069368
# 7   heidiStraightW    0.416585   -0.374331    0.574468    0.035432
# 8   hoshantStraigh    0.400480   -0.583705   -0.565326    0.145026
# 9   ismail2Straigh    0.302428   -0.454693    0.876858   -0.002075
# 10  janahStraightW    0.360441   -0.303924    0.248520    0.083990
# 11  janqhStraightW    0.098203   -0.235560    0.251350   -0.045700
# 12  KarenxStraight    0.207348   -0.123532    0.306170   -0.000423
# ...

# %%
label_column = 'name'
label_encoder = LabelEncoder()
df[label_column] = label_encoder.fit_transform(df[label_column])

# %%
df
# Out:
#     name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     11    0.021361   -0.492503    0.570440    0.071714   -0.301920
# 1     12    0.227064    0.077312    0.562713    0.007784   -0.260888
# 2     13    0.106776   -0.202852    0.336103    0.009316   -0.033247
# 3     14    0.199047   -0.376709   -0.277852    0.070494   -0.023524
# 4     15    0.259229   -0.118446   -0.035600    0.044112    0.082508
# 5     16    0.118827    0.031905   -0.080278   -0.016580   -0.169234
# 6     17    0.100317   -0.638231    0.779516    0.069368   -0.301781
# 7     18    0.416585   -0.374331    0.574468    0.035432   -0.212118
# 8     19    0.400480   -0.583705   -0.565326    0.145026   -0.508438
# 9     20    0.302428   -0.454693    0.876858   -0.002075    0.048715
# 10    21    0.360441   -0.303924    0.248520    0.083990   -0.246797
# 11    22    0.098203   -0.235560    0.251350   -0.045700    0.445139
# 12     0    0.207348   -0.123532    0.306170   -0.000423   -0.048408
# ...

# %%
df_testingHalf = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])
directory = os.path.join(os.getcwd(), 'straightWalk\\testing')
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        testOriginal = pd.read_csv(filepath)
        test=testOriginal.copy()
        
#         num_rows = test.shape[0]
#         start_row = 0
#         end_row = num_rows/2
#         end_row = math.ceil(end_row)

#         num_rows_before = test.shape[0]
    
#         fivePercent = num_rows_before * 0.15
#         fivePercent = math.ceil(fivePercent)
        
#         #test = test.iloc[fivePercent:]
#         test = test.iloc[:-fivePercent]
        
        num_rows = test.shape[0]
        
    
        end_row_init = num_rows/2
        end_row_init = math.ceil(end_row_init)
        
        start_row = end_row_init
        end_row=num_rows+1
        
        
        #print(fivePercent)   
        # Create a new row of data
        new_row = [filepath[53:67],test['LA(x)'][start_row:end_row].mean(),test['LA(y)'][start_row:end_row].mean(),test['LA(z)'][start_row:end_row].mean(),test['GY(x)'][start_row:end_row].mean(),test['GY(y)'][start_row:end_row].mean(),test['GY(z)'][start_row:end_row].mean(),test['LA(x)'][start_row:end_row].std(),test['LA(y)'][start_row:end_row].std(),test['LA(z)'][start_row:end_row].std(),test['GY(x)'][start_row:end_row].std(),test['GY(y)'][start_row:end_row].std(),test['GY(z)'][start_row:end_row].std()]

        # Add the new row to the DataFrame
        df_testingHalf.loc[len(df_testingHalf)] = new_row

# %%
df_testingHalf
# Out:
#              name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0  \seifanaStraig   -0.083939   -0.489550   -0.366760    0.144081    0.031739
# 1  \seifzakariaxS    0.207211   -0.740756    0.715096    0.032814    0.018173
# 2  \tokhye2Straig    0.333276   -0.727371    0.689231    0.180630   -0.309772
# 3  \waedhatemxStr    0.158422   -0.400362   -0.088026    0.143528   -0.009051
# 4  \yaseenriadStr    0.215215   -0.473558    0.302208    0.228795    0.373431
# 5  \youssefemad2x    0.236220   -0.276097   -0.259702    0.030542    0.370067
# 6  \youssefStraig   -0.116796   -0.787395   -0.603033   -0.253052   -0.402129
# 7  \YusufStraight    0.191034    0.237803    0.552329    0.024555    0.355673
# 8  \zoz5xStraight    0.051429    0.085291   -0.001517   -0.164310   -0.349749
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0    0.058185  2.728629  2.958276  3.877483  1.383829  1.506022  0.635918
# ...

# %%
label_column = 'name'
label_encoder = LabelEncoder()
df[label_column] = label_encoder.fit_transform(df[label_column])

# %%
df
# Out:
#     name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     11    0.021361   -0.492503    0.570440    0.071714   -0.301920
# 1     12    0.227064    0.077312    0.562713    0.007784   -0.260888
# 2     13    0.106776   -0.202852    0.336103    0.009316   -0.033247
# 3     14    0.199047   -0.376709   -0.277852    0.070494   -0.023524
# 4     15    0.259229   -0.118446   -0.035600    0.044112    0.082508
# 5     16    0.118827    0.031905   -0.080278   -0.016580   -0.169234
# 6     17    0.100317   -0.638231    0.779516    0.069368   -0.301781
# 7     18    0.416585   -0.374331    0.574468    0.035432   -0.212118
# 8     19    0.400480   -0.583705   -0.565326    0.145026   -0.508438
# 9     20    0.302428   -0.454693    0.876858   -0.002075    0.048715
# 10    21    0.360441   -0.303924    0.248520    0.083990   -0.246797
# 11    22    0.098203   -0.235560    0.251350   -0.045700    0.445139
# 12     0    0.207348   -0.123532    0.306170   -0.000423   -0.048408
# ...

# %%
encodedNames = df.loc[23:, 'name'].values
print(encodedNames)
# Out:
# [ 3  4  5  6  7  9  8  2 10]

# %%
df_testingHalf['name'] = encodedNames
df_testingHalf
# Out:
#    name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     3   -0.083939   -0.489550   -0.366760    0.144081    0.031739
# 1     4    0.207211   -0.740756    0.715096    0.032814    0.018173
# 2     5    0.333276   -0.727371    0.689231    0.180630   -0.309772
# 3     6    0.158422   -0.400362   -0.088026    0.143528   -0.009051
# 4     7    0.215215   -0.473558    0.302208    0.228795    0.373431
# 5     9    0.236220   -0.276097   -0.259702    0.030542    0.370067
# 6     8   -0.116796   -0.787395   -0.603033   -0.253052   -0.402129
# 7     2    0.191034    0.237803    0.552329    0.024555    0.355673
# 8    10    0.051429    0.085291   -0.001517   -0.164310   -0.349749
#
#    mean_GY(z)  sd_LA(x)  sd_LA(y)  sd_LA(z)  sd_GY(x)  sd_GY(y)  sd_GY(z)
# 0    0.058185  2.728629  2.958276  3.877483  1.383829  1.506022  0.635918
# 1   -0.246123  4.949719  4.789671  5.370328  1.295914  1.495981  1.205770
# ...

# %%
df_with_names = df.copy()
y_training_labels = df.pop('name')
y_training_labels
# Out:
# 0     11
# 1     12
# 2     13
# 3     14
# 4     15
# 5     16
# 6     17
# 7     18
# 8     19
# 9     20
# 10    21
# 11    22
# 12     0
# 13    23
# 14    24
# 15    25
# 16     1
# 17    26
# 18    27
# 19    28
# 20    29
# 21    30
# 22    31
# 23     3
# 24     4
# 25     5
# 26     6
# 27     7
# 28     9
# 29     8
# 30     2
# 31    10
# Name: name, dtype: int64

# %%
X_training_dataset = df.copy()

# %%
X_testing_dataset = df_testingHalf.copy()

# %%
y_testing_labels = X_testing_dataset.pop('name')

# %%
X_training_dataset.shape
# Out:
# (32, 12)

# %%
y_training_labels.shape
# Out:
# (32,)

# %%
X_testing_dataset.shape
# Out:
# (9, 12)

# %%
y_testing_labels.shape
# Out:
# (9,)

# %%
classifier = svm.SVC(kernel='linear', gamma='auto', C=2)

classifier.fit(X_training_dataset,y_training_labels)

y_testing_predict = classifier.predict(X_testing_dataset)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_testing_labels,y_testing_predict))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         1
#            9       1.00      1.00      1.00         1
#           10       1.00      1.00      1.00         1
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#
#     accuracy                           0.67         9
#    macro avg       0.50      0.50      0.50         9
# weighted avg       0.67      0.67      0.67         9
# ...

# %%
#Create a svm Classifier
model = svm.SVC(C = 2, # reg paramater
                kernel='linear', #kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
               ) # Linear Kernel

#Train the model using the training sets
model.fit(X_training_dataset, y_training_labels)

#Predict the response for test dataset
y_pred = model.predict(X_testing_dataset)

from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
# Out:
# Accuracy: 0.6666666666666666

# %%
from sklearn import metrics
y_pred = model.predict(X_training_dataset)
print("Accuracy:",metrics.accuracy_score(y_training_labels, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
# Out:
# Accuracy: 0.6666666666666666

# %%
directory = os.path.join(os.getcwd(), 'backpack')
df_backpack = pd.DataFrame(columns=['name','mean_LA(x)', 'mean_LA(y)', 'mean_LA(z)', 'mean_GY(x)', 'mean_GY(y)', 'mean_GY(z)','sd_LA(x)', 'sd_LA(y)', 'sd_LA(z)', 'sd_GY(x)', 'sd_GY(y)', 'sd_GY(z)'])
x=1
firstTime = True
for filename in os.listdir(directory):
    if (filename.endswith(".csv")):
        filepath = os.path.join(directory, filename)
        testOriginal = pd.read_csv(filepath)
        test=testOriginal.copy()
        
        
#         num_rows_before = test.shape[0]
    
#         fivePercent = num_rows_before * 0.15
#         fivePercent = math.ceil(fivePercent)
        
#         test = test.iloc[fivePercent:]
#         test = test.iloc[:-fivePercent]
        
        num_rows = test.shape[0]
        # Create a new row of data
        fileName = filepath[42:]
        fileName = fileName[:-4]
        new_row = [fileName,test['LA(x)'].mean(),test['LA(y)'].mean(),test['LA(z)'].mean(),test['GY(x)'].mean(),test['GY(y)'].mean(),test['GY(z)'].mean(),test['LA(x)'].std(),test['LA(y)'].std(),test['LA(z)'].std(),test['GY(x)'].std(),test['GY(y)'].std(),test['GY(z)'].std()]

        # Add the new row to the DataFrame
        df_backpack.loc[len(df_backpack)] = new_row

# %%
df_backpack
# Out:
#    name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0     0    0.046161   -0.177366    0.273126    0.083461    0.473293
# 1    12    0.363571    0.069023    0.572403   -0.010268   -0.341729
# 2    13    0.129891   -0.280602    0.404590    0.010734   -0.048977
# 3    14    0.129481   -0.465924   -0.382112    0.003880   -0.428910
# 4    15    0.193322   -0.171868   -0.135435    0.060975   -0.170864
# 5    16    0.211621    0.080632    0.379176    0.014446   -0.306127
# 6    17   -0.055617   -0.581031    0.511967    0.030452    0.194445
# 7    18    0.622169   -0.605830    0.830772   -0.012212   -0.537654
# 8    19    0.406965   -0.486983   -0.452831    0.090536   -0.485689
# 9     2    0.134305    0.226199    0.587641    0.060351    0.387851
# 10   20   -0.007947   -0.534358   -0.646322    0.075426   -0.295075
# 11   21    0.073050   -0.189210    0.273689   -0.062134    0.582114
# 12   23    0.115694   -0.148856    0.491282    0.182298   -0.373314
# ...

# %%
X_backpack_dataset = df_backpack.copy()
y_backpack_labels = X_backpack_dataset.pop('name')
X_backpack_dataset
# Out:
#     mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  mean_GY(z)  \
# 0     0.046161   -0.177366    0.273126    0.083461    0.473293   -0.023080
# 1     0.363571    0.069023    0.572403   -0.010268   -0.341729   -0.203385
# 2     0.129891   -0.280602    0.404590    0.010734   -0.048977   -0.161656
# 3     0.129481   -0.465924   -0.382112    0.003880   -0.428910    0.108073
# 4     0.193322   -0.171868   -0.135435    0.060975   -0.170864    0.040031
# 5     0.211621    0.080632    0.379176    0.014446   -0.306127    0.054476
# 6    -0.055617   -0.581031    0.511967    0.030452    0.194445   -0.152689
# 7     0.622169   -0.605830    0.830772   -0.012212   -0.537654   -0.234718
# 8     0.406965   -0.486983   -0.452831    0.090536   -0.485689    0.098626
# 9     0.134305    0.226199    0.587641    0.060351    0.387851   -0.030799
# 10   -0.007947   -0.534358   -0.646322    0.075426   -0.295075    0.094791
# ...

# %%
y_backpack_labels
# Out:
# 0      0
# 1     12
# 2     13
# 3     14
# 4     15
# 5     16
# 6     17
# 7     18
# 8     19
# 9      2
# 10    20
# 11    21
# 12    23
# 13    24
# 14    25
# 15    26
# 16    28
# 17    29
# 18     3
# 19    30
# 20    31
# 21     4
# 22     5
# 23     7
# 24     8
# 25     9
# Name: name, dtype: object

# %%
y_pred = model.predict(X_backpack_dataset)
print("Accuracy:",metrics.accuracy_score(y_backpack_labels, y_pred))
# Out:
# Accuracy: 0.0

# %%
merged_df = pd.concat([df_with_names, df_backpack], axis=0)
merged_df
# Out:
#    name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0    11    0.021361   -0.492503    0.570440    0.071714   -0.301920
# 1    12    0.227064    0.077312    0.562713    0.007784   -0.260888
# 2    13    0.106776   -0.202852    0.336103    0.009316   -0.033247
# 3    14    0.199047   -0.376709   -0.277852    0.070494   -0.023524
# 4    15    0.259229   -0.118446   -0.035600    0.044112    0.082508
# 5    16    0.118827    0.031905   -0.080278   -0.016580   -0.169234
# 6    17    0.100317   -0.638231    0.779516    0.069368   -0.301781
# 7    18    0.416585   -0.374331    0.574468    0.035432   -0.212118
# 8    19    0.400480   -0.583705   -0.565326    0.145026   -0.508438
# 9    20    0.302428   -0.454693    0.876858   -0.002075    0.048715
# 10   21    0.360441   -0.303924    0.248520    0.083990   -0.246797
# 11   22    0.098203   -0.235560    0.251350   -0.045700    0.445139
# 12    0    0.207348   -0.123532    0.306170   -0.000423   -0.048408
# ...

# %%
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#    name  mean_LA(x)  mean_LA(y)  mean_LA(z)  mean_GY(x)  mean_GY(y)  \
# 0    11    0.021361   -0.492503    0.570440    0.071714   -0.301920
# 1    12    0.227064    0.077312    0.562713    0.007784   -0.260888
# 2    13    0.106776   -0.202852    0.336103    0.009316   -0.033247
# 3    14    0.199047   -0.376709   -0.277852    0.070494   -0.023524
# 4    15    0.259229   -0.118446   -0.035600    0.044112    0.082508
# 5    16    0.118827    0.031905   -0.080278   -0.016580   -0.169234
# 6    17    0.100317   -0.638231    0.779516    0.069368   -0.301781
# 7    18    0.416585   -0.374331    0.574468    0.035432   -0.212118
# 8    19    0.400480   -0.583705   -0.565326    0.145026   -0.508438
# 9    20    0.302428   -0.454693    0.876858   -0.002075    0.048715
# 10   21    0.360441   -0.303924    0.248520    0.083990   -0.246797
# 11   22    0.098203   -0.235560    0.251350   -0.045700    0.445139
# 12    0    0.207348   -0.123532    0.306170   -0.000423   -0.048408
# ...

# %%
#Create a svm Classifier
model2 = svm.SVC(C = 2, # reg paramater
                kernel='linear', #kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
               ) # Linear Kernel

#Train the model using the training sets
model.fit(X_training_dataset, y_training_labels)

#Predict the response for test dataset
y_pred = model.predict(X_testing_dataset)

from sklearn import metrics
y_pred = model.predict(X_testing_dataset)
print("Accuracy:",metrics.accuracy_score(y_testing_labels, y_pred))
